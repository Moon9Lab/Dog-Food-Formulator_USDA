# %%
import pandas as pd
import requests
import os
from dotenv import load_dotenv
from tabulate import tabulate

# Load environment variables from .env file
load_dotenv()

# Get the USDA API key from the environment variable
USDA_API_KEY = os.getenv("USDA_API_KEY")

# Function#1.1 to fetch food details from USDA API given an FDC ID
def fetch_food_details(fdc_id, api_key=USDA_API_KEY):
    url = f"https://api.nal.usda.gov/fdc/v1/food/{fdc_id}?api_key={api_key}"
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Error fetching food details. Status code: {response.status_code}")
        return None
    try:
        return response.json()
    except Exception as e:
        print(f"Error decoding JSON response: {e}")

# Function#1.2 to convert the "food_details" variable to a Markdown table
def food_details_to_markdown(food_details):
    # Fetch the food name from the API response and keep only the first part before the comma
    full_food_name = food_details.get('description', 'Unknown')
    food_name = full_food_name.split(',')[0]
    
    food_nutrients_list = food_details.get('foodNutrients', [])
    df_food_nutrients = pd.DataFrame(columns=['Nutrient', 'Unit', food_name])
    
    for item in food_nutrients_list:
        nutrient_name = item.get('nutrient', {}).get('name', 'Unknown')
        amount = item.get('amount', 'N/A')
        unit = item.get('nutrient', {}).get('unitName', 'N/A')
        
        new_row = pd.DataFrame({'Nutrient': [nutrient_name], food_name: [amount], 'Unit': [unit]})
        df_food_nutrients = pd.concat([df_food_nutrients, new_row], ignore_index=True)
    
    markdown_table = tabulate(df_food_nutrients, tablefmt="pipe", headers="keys")
    
    return markdown_table

# Example usage
fdc_id = 169255  # Replace with a valid FDC ID
food_details = fetch_food_details(fdc_id)

if food_details is not None:
    markdown_table_from_food_details = food_details_to_markdown(food_details)
    print(markdown_table_from_food_details)
# Out:
# |     | Nutrient                                 | Unit   | Mushrooms   |
# |----:|:-----------------------------------------|:-------|:------------|
# |   0 | Proximates                               | g      | N/A         |
# |   1 | Water                                    | g      | 92.82       |
# |   2 | Energy                                   | kcal   | 22.0        |
# |   3 | Energy                                   | kJ     | 92.0        |
# |   4 | Protein                                  | g      | 2.11        |
# |   5 | Total lipid (fat)                        | g      | 0.35        |
# |   6 | Ash                                      | g      | 0.85        |
# |   7 | Carbohydrates                            | g      | N/A         |
# |   8 | Carbohydrate, by difference              | g      | 3.87        |
# |   9 | Fiber, total dietary                     | g      | 1.3         |
# |  10 | Sugars, total including NLEA             | g      | 2.5         |
# |  11 | Sucrose                                  | g      | 0.0         |
# |  12 | Glucose                                  | g      | 2.01        |
# |  13 | Fructose                                 | g      | 0.49        |
# |  14 | Lactose                                  | g      | 0.0         |
# |  15 | Maltose                                  | g      | 0.0         |
# |  16 | Galactose                                | g      | 0.0         |
# |  17 | Minerals                                 | mg     | N/A         |
# |  18 | Calcium, Ca                              | mg     | 3.0         |
# |  19 | Iron, Fe                                 | mg     | 0.31        |
# |  20 | Phosphorus, P                            | mg     | 108.0       |
# |  21 | Potassium, K                             | mg     | 364.0       |
# |  22 | Sodium, Na                               | mg     | 9.0         |
# |  23 | Zinc, Zn                                 | mg     | 0.53        |
# |  24 | Copper, Cu                               | mg     | 0.286       |
# |  25 | Manganese, Mn                            | mg     | 0.069       |
# |  26 | Selenium, Se                             | µg     | 18.6        |
# |  27 | Vitamins and Other Components            | g      | N/A         |
# |  28 | Vitamin C, total ascorbic acid           | mg     | 0.0         |
# |  29 | Thiamin                                  | mg     | 0.059       |
# |  30 | Riboflavin                               | mg     | 0.13        |
# |  31 | Niacin                                   | mg     | 4.494       |
# |  32 | Pantothenic acid                         | mg     | 1.14        |
# |  33 | Vitamin B-6                              | mg     | 0.148       |
# |  34 | Folate, total                            | µg     | 28.0        |
# |  35 | Folic acid                               | µg     | 0.0         |
# |  36 | Folate, food                             | µg     | 28.0        |
# |  37 | Folate, DFE                              | µg     | 28.0        |
# |  38 | Choline, total                           | mg     | 21.2        |
# |  39 | Betaine                                  | mg     | 6.1         |
# |  40 | Vitamin B-12                             | µg     | 0.05        |
# |  41 | Vitamin B-12, added                      | µg     | 0.0         |
# |  42 | Vitamin A, RAE                           | µg     | 0.0         |
# |  43 | Retinol                                  | µg     | 0.0         |
# |  44 | Carotene, beta                           | µg     | 0.0         |
# |  45 | Carotene, alpha                          | µg     | 0.0         |
# |  46 | Cryptoxanthin, beta                      | µg     | 0.0         |
# |  47 | Vitamin A, IU                            | IU     | 0.0         |
# |  48 | Lycopene                                 | µg     | 0.0         |
# |  49 | Lutein + zeaxanthin                      | µg     | 0.0         |
# |  50 | Vitamin E (alpha-tocopherol)             | mg     | 0.02        |
# |  51 | Vitamin E, added                         | mg     | 0.0         |
# |  52 | Tocopherol, beta                         | mg     | 0.0         |
# |  53 | Tocopherol, gamma                        | mg     | 0.0         |
# |  54 | Tocopherol, delta                        | mg     | 0.0         |
# |  55 | Tocotrienol, alpha                       | mg     | 0.02        |
# |  56 | Tocotrienol, beta                        | mg     | 0.0         |
# |  57 | Tocotrienol, gamma                       | mg     | 0.0         |
# |  58 | Tocotrienol, delta                       | mg     | 0.0         |
# |  59 | Vitamin D (D2 + D3), International Units | IU     | 10.0        |
# |  60 | Vitamin D (D2 + D3)                      | µg     | 0.3         |
# |  61 | Vitamin D2 (ergocalciferol)              | µg     | 0.3         |
# |  62 | Vitamin D3 (cholecalciferol)             | µg     | 0.0         |
# |  63 | Vitamin K (phylloquinone)                | µg     | 0.0         |
# |  64 | Vitamin K (Dihydrophylloquinone)         | µg     | 1.8         |
# |  65 | Vitamin K (Menaquinone-4)                | µg     | 0.0         |
# |  66 | Lipids                                   | g      | N/A         |
# |  67 | Fatty acids, total saturated             | g      | 0.01        |
# |  68 | SFA 4:0                                  | g      | 0.0         |
# |  69 | SFA 15:0                                 | g      | 0.003       |
# |  70 | SFA 17:0                                 | g      | 0.003       |
# |  71 | SFA 20:0                                 | g      | 0.003       |
# |  72 | SFA 22:0                                 | g      | 0.003       |
# |  73 | SFA 24:0                                 | g      | 0.0         |
# |  74 | Fatty acids, total monounsaturated       | g      | 0.044       |
# |  75 | MUFA 14:1                                | g      | 0.001       |
# |  76 | MUFA 15:1                                | g      | 0.0         |
# |  77 | MUFA 16:1                                | g      | 0.008       |
# |  78 | MUFA 16:1 c                              | g      | 0.005       |
# |  79 | MUFA 17:1                                | g      | 0.0         |
# |  80 | MUFA 18:1                                | g      | 0.016       |
# |  81 | MUFA 18:1 c                              | g      | 0.014       |
# |  82 | MUFA 22:1                                | g      | 0.0         |
# |  83 | MUFA 22:1 c                              | g      | 0.0         |
# |  84 | MUFA 24:1 c                              | g      | 0.0         |
# |  85 | Fatty acids, total polyunsaturated       | g      | 0.296       |
# |  86 | PUFA 18:2                                | g      | 0.148       |
# |  87 | PUFA 18:2 n-6 c,c                        | g      | 0.148       |
# |  88 | PUFA 18:2 CLAs                           | g      | 0.0         |
# |  89 | PUFA 18:3                                | g      | 0.0         |
# |  90 | PUFA 18:3 n-3 c,c,c (ALA)                | g      | 0.0         |
# |  91 | PUFA 18:3 n-6 c,c,c                      | g      | 0.0         |
# |  92 | PUFA 20:2 n-6 c,c                        | g      | 0.0         |
# |  93 | PUFA 20:3                                | g      | 0.0         |
# |  94 | PUFA 20:3 n-3                            | g      | 0.0         |
# |  95 | PUFA 20:3 n-6                            | g      | 0.0         |
# |  96 | PUFA 22:4                                | g      | 0.0         |
# |  97 | Fatty acids, total trans                 | g      | 0.0         |
# |  98 | Fatty acids, total trans-monoenoic       | g      | 0.0         |
# |  99 | TFA 16:1 t                               | g      | 0.0         |
# | 100 | TFA 18:1 t                               | g      | 0.0         |
# | 101 | TFA 22:1 t                               | g      | 0.0         |
# | 102 | TFA 18:2 t not further defined           | g      | 0.0         |
# | 103 | Fatty acids, total trans-polyenoic       | g      | 0.0         |
# | 104 | Cholesterol                              | mg     | 0.0         |
# | 105 | Phytosterols                             | mg     | N/A         |
# | 106 | Stigmasterol                             | mg     | 0.0         |
# | 107 | Campesterol                              | mg     | 2.0         |
# | 108 | Beta-sitosterol                          | mg     | 0.0         |
# | 109 | Amino acids                              | g      | N/A         |
# | 110 | Tryptophan                               | g      | 0.035       |
# | 111 | Threonine                                | g      | 0.101       |
# | 112 | Isoleucine                               | g      | 0.082       |
# | 113 | Leucine                                  | g      | 0.13        |
# | 114 | Lysine                                   | g      | 0.122       |
# | 115 | Methionine                               | g      | 0.029       |
# | 116 | Cystine                                  | g      | 0.01        |
# | 117 | Phenylalanine                            | g      | 0.076       |
# | 118 | Tyrosine                                 | g      | 0.014       |
# | 119 | Valine                                   | g      | 0.076       |
# | 120 | Arginine                                 | g      | 0.082       |
# | 121 | Histidine                                | g      | 0.058       |
# | 122 | Alanine                                  | g      | 0.168       |
# | 123 | Aspartic acid                            | g      | 0.221       |
# | 124 | Glutamic acid                            | g      | 0.319       |
# | 125 | Glycine                                  | g      | 0.096       |
# | 126 | Proline                                  | g      | 0.076       |
# | 127 | Serine                                   | g      | 0.092       |
# | 128 | Alcohol, ethyl                           | g      | 0.0         |
# | 129 | Caffeine                                 | mg     | 0.0         |
# | 130 | Theobromine                              | mg     | 0.0         |

# %%
import pandas as pd
import requests
import os
from dotenv import load_dotenv
from tabulate import tabulate

# Load environment variables from .env file
load_dotenv("../Credential/.env")

# Get the USDA API key from the environment variable
USDA_API_KEY = os.getenv("USDA_API_KEY")

# Function#1 to fetch food details from USDA API given an FDC ID
def fetch_food_details(fdc_id, api_key=USDA_API_KEY):
    url = f"https://api.nal.usda.gov/fdc/v1/food/{fdc_id}?api_key={api_key}"
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Error fetching food details. Status code: {response.status_code}")
        return None
    try:
        return response.json()
    except Exception as e:
        print(f"Error decoding JSON response: {e}")
        return None

# Function#2 to fetch and scale nutrients for a single food item
def fetch_and_scale_nutrients(fdc_id, grams):
    food_details = fetch_food_details(fdc_id)
    if food_details is None:
        return None
    
    food_name = food_details.get('description', 'Unknown').split(',')[0]
    food_nutrients_list = food_details.get('foodNutrients', [])
    
    df_food_nutrients = pd.DataFrame(columns=['Nutrient', 'Unit', food_name])
    
    for item in food_nutrients_list:
        nutrient_name = item.get('nutrient', {}).get('name', 'Unknown')
        amount_per_100g = item.get('amount', 'N/A')
        unit = item.get('nutrient', {}).get('unitName', 'N/A')
        
        if amount_per_100g != 'N/A':
            scaled_amount = (amount_per_100g * grams) / 100.0
            scaled_amount = round(scaled_amount, 2)  # Round to two decimal places
        else:
            scaled_amount = 'N/A'
        
        new_row = pd.DataFrame({'Nutrient': [nutrient_name], food_name: [scaled_amount], 'Unit': [unit]})
        df_food_nutrients = pd.concat([df_food_nutrients, new_row], ignore_index=True)
    
    return df_food_nutrients

# Function#3 to aggregate nutrients from multiple food items
def aggregate_nutrients(df_list):
    df_aggregated = pd.concat(df_list, ignore_index=True)
    
    # Group by 'Nutrient' and 'Unit', and sum the nutrient values
    df_aggregated = df_aggregated.groupby(['Nutrient', 'Unit']).sum().reset_index()
    
    # Replace 'N/A' with 0.0 for numerical operations
    df_aggregated.replace('N/A', 0.0, inplace=True)
    
    # Create a 'Sum' column that sums up the nutrient values for each nutrient type
    df_aggregated['Sum'] = df_aggregated.iloc[:, 2:].sum(axis=1).astype('float64').round(2)
    
    # Reorder the columns to place 'Sum' before each individual food column
    cols = df_aggregated.columns.tolist()
    reordered_cols = cols[:2] + ['Sum'] + cols[2:-1]
    df_aggregated = df_aggregated[reordered_cols]
    
    return df_aggregated

# Main function
def main():
    food_list = [
        {"Food": "Blueberries", "fdc_id": 173950, "gram": 100},
        {"Food": "Broccoli", "fdc_id": 170379, "gram": 100},
    ]
    
    df_list = []
    
    for food_item in food_list:
        df = fetch_and_scale_nutrients(food_item['fdc_id'], food_item['gram'])
        if df is not None:
            df_list.append(df)
    
    df_aggregated = aggregate_nutrients(df_list)
    
    # Export the aggregated DataFrame to a CSV file
    #df_aggregated.to_csv("aggregated_nutrients.csv", index=False)
    #print("Aggregated nutrients data has been exported to 'aggregated_nutrients.csv'.")
    
    print(tabulate(df_aggregated, tablefmt="plain", headers="keys"))

# Run the main function
if __name__ == "__main__":
    main()
# Out:
#      Nutrient                                  Unit        Sum    Blueberries    Broccoli
#   0  Alanine                                   g          0.12           0.02        0.1
#   1  Alcohol, ethyl                            g          0              0           0
#   2  Amino acids                               g          0              0           0
#   3  Arginine                                  g          0.21           0.02        0.19
#   4  Ash                                       g          1.05           0.18        0.87
#   5  Aspartic acid                             g          0.36           0.03        0.33
#   6  Betaine                                   mg         0.1            0           0.1
#   7  Caffeine                                  mg         0              0           0
#   8  Calcium, Ca                               mg        55              8          47
#   9  Carbohydrate, by difference               g         18.81          12.17        6.64
#  10  Carbohydrates                             g          0              0           0
#  11  Carotene, alpha                           µg        25              0          25
#  12  Carotene, beta                            µg       389             28         361
#  13  Cholesterol                               mg         0              0           0
#  14  Choline, total                            mg        23.8            5.1        18.7
#  15  Copper, Cu                                mg         0.08           0.03        0.05
#  16  Cryptoxanthin, beta                       µg         1              0           1
#  17  Cystine                                   g          0.03           0           0.03
#  18  Energy                                    kJ       354            213         141
#  19  Energy                                    kcal      85             51          34
#  20  Fatty acids, total monounsaturated        g          0.12           0.09        0.03
#  21  Fatty acids, total polyunsaturated        g          0.39           0.28        0.11
#  22  Fatty acids, total saturated              g          0.16           0.05        0.11
#  23  Fatty acids, total trans                  g          0              0           0
#  24  Fiber, total dietary                      g          5.3            2.7         2.6
#  25  Folate, DFE                               µg        70              7          63
#  26  Folate, food                              µg        70              7          63
#  27  Folate, total                             µg        70              7          63
#  28  Folic acid                                µg         0              0           0
#  29  Fructose                                  g          0.68           0           0.68
#  30  Galactose                                 g          0              0           0
#  31  Glucose                                   g          0.49           0           0.49
#  32  Glutamic acid                             g          0.59           0.05        0.54
#  33  Glycine                                   g          0.11           0.02        0.09
#  34  Histidine                                 g          0.07           0.01        0.06
#  35  Iron, Fe                                  mg         0.91           0.18        0.73
#  36  Isoleucine                                g          0.09           0.01        0.08
#  37  Lactose                                   g          0.21           0           0.21
#  38  Leucine                                   g          0.16           0.03        0.13
#  39  Lipids                                    g          0              0           0
#  40  Lutein + zeaxanthin                       µg      1471             68        1403
#  41  Lycopene                                  µg         0              0           0
#  42  Lysine                                    g          0.15           0.01        0.14
#  43  MUFA 14:1                                 g          0              0           0
#  44  MUFA 15:1                                 g          0              0           0
#  45  MUFA 16:1                                 g          0              0           0
#  46  MUFA 17:1                                 g          0              0           0
#  47  MUFA 18:1                                 g          0.12           0.09        0.03
#  48  MUFA 20:1                                 g          0              0           0
#  49  MUFA 22:1                                 g          0              0           0
#  50  Magnesium, Mg                             mg        26              5          21
#  51  Maltose                                   g          0.21           0           0.21
#  52  Manganese, Mn                             mg         0.36           0.15        0.21
#  53  Methionine                                g          0.05           0.01        0.04
#  54  Minerals                                  mg         0              0           0
#  55  Niacin                                    mg         1.16           0.52        0.64
#  56  PUFA 18:2                                 g          0.22           0.17        0.05
#  57  PUFA 18:3                                 g          0.17           0.11        0.06
#  58  PUFA 18:3 n-6 c,c,c                       g          0              0           0
#  59  PUFA 18:4                                 g          0              0           0
#  60  PUFA 20:2 n-6 c,c                         g          0              0           0
#  61  PUFA 20:3                                 g          0              0           0
#  62  PUFA 20:4                                 g          0              0           0
#  63  PUFA 20:5 n-3 (EPA)                       g          0              0           0
#  64  PUFA 22:5 n-3 (DPA)                       g          0              0           0
#  65  PUFA 22:6 n-3 (DHA)                       g          0              0           0
#  66  Pantothenic acid                          mg         0.69           0.12        0.57
#  67  Phenylalanine                             g          0.13           0.01        0.12
#  68  Phosphorus, P                             mg        77             11          66
#  69  Potassium, K                              mg       370             54         316
#  70  Proline                                   g          0.12           0.01        0.11
#  71  Protein                                   g          3.24           0.42        2.82
#  72  Proximates                                g          0              0           0
#  73  Retinol                                   µg         0              0           0
#  74  Riboflavin                                mg         0.16           0.04        0.12
#  75  SFA 10:0                                  g          0              0           0
#  76  SFA 12:0                                  g          0              0           0
#  77  SFA 14:0                                  g          0              0           0
#  78  SFA 15:0                                  g          0              0           0
#  79  SFA 16:0                                  g          0.11           0.03        0.08
#  80  SFA 17:0                                  g          0              0           0
#  81  SFA 18:0                                  g          0.03           0.01        0.02
#  82  SFA 20:0                                  g          0.01           0           0.01
#  83  SFA 22:0                                  g          0              0           0
#  84  SFA 4:0                                   g          0              0           0
#  85  SFA 6:0                                   g          0              0           0
#  86  SFA 8:0                                   g          0              0           0
#  87  Selenium, Se                              µg         2.6            0.1         2.5
#  88  Serine                                    g          0.13           0.01        0.12
#  89  Sodium, Na                                mg        34              1          33
#  90  Starch                                    g          0              0           0
#  91  Sucrose                                   g          0.1            0           0.1
#  92  Sugars, total including NLEA              g         10.15           8.45        1.7
#  93  Theobromine                               mg         0              0           0
#  94  Thiamin                                   mg         0.1            0.03        0.07
#  95  Threonine                                 g          0.1            0.01        0.09
#  96  Tocopherol, beta                          mg         0.01           0           0.01
#  97  Tocopherol, delta                         mg         0              0           0
#  98  Tocopherol, gamma                         mg         0.17           0           0.17
#  99  Tocotrienol, alpha                        mg         0.04           0           0.04
# 100  Tocotrienol, beta                         mg         0              0           0
# 101  Tocotrienol, delta                        mg         0              0           0
# 102  Tocotrienol, gamma                        mg         0              0           0
# 103  Total lipid (fat)                         g          1.01           0.64        0.37
# 104  Tryptophan                                g          0.03           0           0.03
# 105  Tyrosine                                  g          0.06           0.01        0.05
# 106  Valine                                    g          0.14           0.02        0.12
# 107  Vitamin A, IU                             IU       669             46         623
# 108  Vitamin A, RAE                            µg        33              2          31
# 109  Vitamin B-12                              µg         0              0           0
# 110  Vitamin B-12, added                       µg         0              0           0
# 111  Vitamin B-6                               mg         0.23           0.06        0.17
# 112  Vitamin C, total ascorbic acid            mg        91.7            2.5        89.2
# 113  Vitamin D (D2 + D3)                       µg         0              0           0
# 114  Vitamin D (D2 + D3), International Units  IU         0              0           0
# 115  Vitamin E (alpha-tocopherol)              mg         1.26           0.48        0.78
# 116  Vitamin E, added                          mg         0              0           0
# 117  Vitamin K (Dihydrophylloquinone)          µg         0              0           0
# 118  Vitamin K (phylloquinone)                 µg       118             16.4       101.6
# 119  Vitamins and Other Components             g          0              0           0
# 120  Water                                     g        175.89          86.59       89.3
# 121  Zinc, Zn                                  mg         0.48           0.07        0.41

# %%
import pandas as pd
import requests
import os
from dotenv import load_dotenv
from tabulate import tabulate
import matplotlib.pyplot as plt

# Load environment variables from .env file
load_dotenv("../Credential/.env")

# Get the USDA API key from the environment variable
USDA_API_KEY = os.getenv("USDA_API_KEY")

# Function#1 to fetch food details from USDA API given an FDC ID
def fetch_food_details(fdc_id, api_key=USDA_API_KEY):
    url = f"https://api.nal.usda.gov/fdc/v1/food/{fdc_id}?api_key={api_key}"
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Error fetching food details. Status code: {response.status_code}")
        return None
    try:
        return response.json()
    except Exception as e:
        print(f"Error decoding JSON response: {e}")
        return None

# Function#2 to fetch and scale nutrients for a single food item
def fetch_and_scale_nutrients(fdc_id, grams):
    food_details = fetch_food_details(fdc_id)
    if food_details is None:
        return None
    
    food_name = food_details.get('description', 'Unknown').split(',')[0]
    food_nutrients_list = food_details.get('foodNutrients', [])
    
    df_food_nutrients = pd.DataFrame(columns=['Nutrient', 'Unit', food_name])
    
    for item in food_nutrients_list:
        nutrient_name = item.get('nutrient', {}).get('name', 'Unknown')
        amount_per_100g = item.get('amount', 'N/A')
        unit = item.get('nutrient', {}).get('unitName', 'N/A')
        
        if amount_per_100g != 'N/A':
            scaled_amount = (amount_per_100g * grams) / 100.0
            scaled_amount = round(scaled_amount, 2)  # Round to two decimal places
        else:
            scaled_amount = 'N/A'
        
        new_row = pd.DataFrame({'Nutrient': [nutrient_name], food_name: [scaled_amount], 'Unit': [unit]})
        df_food_nutrients = pd.concat([df_food_nutrients, new_row], ignore_index=True)
    
    return df_food_nutrients

# Function#3 to aggregate nutrients from multiple food items
def aggregate_nutrients(df_list):
    df_aggregated = pd.concat(df_list, ignore_index=True)
    
    # Group by 'Nutrient' and 'Unit', and sum the nutrient values
    df_aggregated = df_aggregated.groupby(['Nutrient', 'Unit']).sum().reset_index()
    
    # Replace 'N/A' with 0.0 for numerical operations
    df_aggregated.replace('N/A', 0.0, inplace=True)
    
    # Create a 'Sum' column that sums up the nutrient values for each nutrient type
    df_aggregated['Sum'] = df_aggregated.iloc[:, 2:].sum(axis=1).astype('float64').round(2)
    
    # Reorder the columns to place 'Sum' before each individual food column
    cols = df_aggregated.columns.tolist()
    reordered_cols = cols[:2] + ['Sum'] + cols[2:-1]
    df_aggregated = df_aggregated[reordered_cols]
    
    return df_aggregated

# Function to plot nutrient density for each category
def plot_nutrient_density(df_aggregated):
    # Define the categories and their corresponding nutrients
    categories = {
        "AAFCO_CC_Protein": ["Protein", "Arginine", "Histidine", "Isoleucine", "Leucine", "Lysine", "Methionine", "Cystine", "Phenylalanine", "Tyrosine", "Threonine", "Tryptophan", "Valine"],
        "AAFCO_CC_Fat": ["Total lipid (fat)", "PUFA 18:3 n-3 c,c,c (ALA)", "PUFA 18:2 n-6 c,c", "PUFA 20:5 n-3 (EPA)", "PUFA 22:6 n-3 (DHA)"],
        "AAFCO_CC_Mineral": ["Calcium, Ca", "Phosphorus, P", "Potassium, K", "Sodium, Na", "Chlorine, Cl", "Magnesium, Mg", "Iron, Fe", "Copper, Cu", "Manganese, Mn", "Zinc, Zn", "Iodine, I", "Selenium, Se"],
        "AAFCO_CC_Vitamins": ["Vitamin A, IU", "Vitamin D (D2 + D3), International Units", "Vitamin E (alpha-tocopherol)", "Thiamin", "Riboflavin", "Pantothenic acid", "Niacin", "Vitamin B-6", "Folic acid", "Vitamin B-12", "Choline, total"]
    }

    
 # Plot each category
    for category, nutrients in categories.items():
        df_filtered = df_aggregated[df_aggregated['Nutrient'].isin(nutrients)]
        
        plt.figure(figsize=(10, 6))
        
        for food in df_filtered.columns[3:]:
            plt.bar(df_filtered['Nutrient'], df_filtered[food], alpha=0.7, label=food)
        
        plt.title(f"{category} Density Comparison")
        plt.xlabel("Nutrient")
        plt.ylabel("Amount")
        plt.xticks(rotation=90)
        plt.legend()
        plt.tight_layout()
        plt.show()
        
# Main function
def main():
    food_list = [
        {"Food": "Blueberries", "fdc_id": 173950, "gram": 100},
        {"Food": "Broccoli", "fdc_id": 170379, "gram": 100},
    ]
    
    df_list = []
    
    for food_item in food_list:
        df = fetch_and_scale_nutrients(food_item['fdc_id'], food_item['gram'])
        if df is not None:
            df_list.append(df)
    
    df_aggregated = aggregate_nutrients(df_list)
    
    
    #print(tabulate(df_aggregated, tablefmt="plain", headers="keys"))
    
    # Export the aggregated DataFrame to a CSV file
    #df_aggregated.to_csv("aggregated_nutrients.csv", index=False)
    #print("Aggregated nutrients data has been exported to 'aggregated_nutrients.csv'.")
    
    # Plot the nutrient density for each category
    plot_nutrient_density(df_aggregated)

# Run the main function
if __name__ == "__main__":
    main()
